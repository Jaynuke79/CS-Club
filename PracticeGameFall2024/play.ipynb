# %%
import pandas as pd

# %%
CSV = pd.read_csv("../orders3.csv")

# %%
CSV["Order ID"].unique().shape
# Out:
# (41,)

# %%
CSV
# Out:
#     Order ID Financial Status Fulfillment Status  Fulfilled at Currency  \
# 0       1334             PAID            pending           NaN      USD
# 1       1333             PAID            pending           NaN      USD
# 2       1332             PAID            pending           NaN      USD
# 3       1331             PAID            pending           NaN      USD
# 4       1331              NaN                NaN           NaN      NaN
# 5       1330             PAID            pending           NaN      USD
# 6       1329             PAID            pending           NaN      USD
# 7       1328             PAID            pending           NaN      USD
# 8       1328              NaN                NaN           NaN      NaN
# 9       1327             PAID            pending           NaN      USD
# 10      1327              NaN                NaN           NaN      NaN
# 11      1326             PAID            pending           NaN      USD
# ...
